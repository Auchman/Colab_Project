# %% [markdown]
# ## **COLAB USING GENERATIVE AI**

# %%
# prompt: create a dataframe that has midterm grades for 100 students

import pandas as pd
import numpy as np

# Create a list of student IDs
student_ids = [f"Student_{i}" for i in range(1, 101)]

# Generate random midterm grades between 60 and 100
midterm_grades = np.random.randint(60, 101, size=100)

# Create a DataFrame
df = pd.DataFrame({"StudentID": student_ids, "MidtermGrade": midterm_grades})

# Print the DataFrame
df
# Out:
#       StudentID  MidtermGrade
# 0     Student_1            76
# 1     Student_2            61
# 2     Student_3            67
# 3     Student_4            63
# 4     Student_5            90
# ..          ...           ...
# 95   Student_96            85
# 96   Student_97            74
# 97   Student_98            82
# 98   Student_99            64
# 99  Student_100            61
#
# [100 rows x 2 columns]

# %%
# @title MidtermGrade

from matplotlib import pyplot as plt
df['MidtermGrade'].plot(kind='hist', bins=20, title='MidtermGrade')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# prompt: how can i create a bar chart using matplotib with line spacing of 10

import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# ... (your existing code to create the df DataFrame) ...


# Create a bar chart with line spacing of 10
plt.figure(figsize=(10, 6))  # Adjust figure size as needed
plt.bar(df.index, df['MidtermGrade'], width=0.8)  # Adjust width as needed
plt.xlabel('Student ID')
plt.ylabel('Midterm Grade')
plt.title('Midterm Grades of Students')
plt.xticks(np.arange(0, len(df), 10), rotation=45)  # Adjust the spacing here
plt.gca().spines[['top', 'right']].set_visible(False)
plt.tight_layout()
plt.show()

# %%
# prompt: What is the good question to ask python students

**Conceptual Questions:**



* **Explain the difference between a list and a dictionary in Python and provide an example where each would be most appropriate.** (Assesses understanding of fundamental data structures)
* **What is the purpose of a function in Python? How can functions improve the organization and readability of your code?** (Assesses understanding of modular programming and code reusability)
* **Describe the concept of loops (for and while) in Python and give an example of how you might use them to perform a specific task.** (Assesses understanding of iterative processes and control flow)
* **What are the benefits of using libraries like Pandas and NumPy for data analysis?** (Assesses understanding of the importance of libraries and their specific use cases)
* **How would you handle an error or exception in a Python program to prevent it from crashing?** (Assesses understanding of error handling and robustness in programming)
* **Explain the concept of object-oriented programming (OOP) and how it relates to Python.** (Assesses understanding of advanced programming concepts)

**Application-Based Questions (Relating to Provided Code):**

* **How could you modify the code to calculate the average midterm grade for all students?** (Assesses understanding of data manipulation and aggregation)
* **Write a function that takes a student's ID as input and returns their corresponding midterm grade from the `df` DataFrame.** (Assesses ability to write functions to interact with data)
* **If you wanted to filter the DataFrame to only show students with a midterm grade above 85, how would you do that?** (Assesses understanding of data filtering and selection)
* **Explain how the provided code uses the `matplotlib` library to visualize the midterm grades. What are the different ways that you can plot the data to convey different information?** (Assesses understanding of data visualization and the purpose of different plot types)
* **How could you sort the DataFrame by midterm grade in descending order to easily identify the top-performing students?** (Assesses understanding of data sorting and manipulation)
* **If you were to add a column to the DataFrame for final exam grades, how would you do it?** (Assesses understanding of data manipulation and adding new data to a DataFrame)



These questions cater to different levels of understanding and allow you to assess a student's ability to:


* Grasp fundamental programming concepts.
* Apply their knowledge to real-world problems.
* Analyze data using Python libraries.
* Visualize and interpret data insights.
* Write clean, efficient, and well-structured code.


Remember to adjust the difficulty level and type of questions based on the specific learning objectives and the level of your students. Good luck!
